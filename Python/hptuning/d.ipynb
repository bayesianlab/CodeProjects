# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# dd=pd.read_csv('data375k.csv')
# insample, remainder = train_test_split(dd, test_size=10000,  random_state=115)

# insample_small = insample.head(1000)

# %%
insample
# Out:
#         MarginPrice   LookId         SellerName HedgeAdvisorName  \
# 328065        0.136   891299          leaderone             resi
# 368288        0.142  1140510  churchillmortgage            other
# 216162        0.590   110218     guaranteedrate            other
# 370077        0.140  1148071          amerisave          compass
# 151163        0.160    45070     guaranteedrate            other
# ...             ...      ...                ...              ...
# 79579         0.333   183042     eustismortgage              mct
# 79504         0.199   182962          leaderone             resi
# 67055         0.224    14647            nexbank          compass
# 270752        0.504  1067177      guildmortgage              mct
# 203538        1.662   198089          victorian              mct
#
#         AbaMemberBit  CommitPeriodGrp   LoanAmt  BaseLoanAmt  NoteRate  \
# 328065             0                7  216000.0     216000.0     6.375
# ...

# %%
remainder
# Out:
#          LookId                      SellerName HedgeAdvisorName  \
# 113743  1048429              baycapitalmortgage              mct
# 136682  1060099                mortgageresearch          compass
# 42579   1041588               southeastmortgage             resi
# 13047   1053853                   southerntrust             resi
# 175325  1037316                     kindlending            other
# ...         ...                             ...              ...
# 79654   1069745                       leaderone             resi
# 28054    633670                       paramount          compass
# 8706     189729                     mifinancial              mct
# 76869    200308        mutualofomahamortgageinc          compass
# 50946    965680  farmingtonfinancialcapstarbank              mct
#
#         AbaMemberBit  CommitPeriodGrp   LoanAmt  BaseLoanAmt  NoteRate  \
# 113743             0                7  418950.0     418950.0     7.625
# ...

# %%
insample.to_csv('insample.csv', index=False)
insample_small.to_csv('insample_small.csv', index=False)
remainder.to_csv('outofsample.csv', index=False)

# %%
x=pd.read_csv('shallow_wide\\hptune_shallow.csv')

# %%
x
# Out:
#    dense_start_S  layersS  dense_0S  dense_start_dM  layersM  dense_0dM  \
# 0            235        2       200             120        3        450
# 1            875        1       850             210        2        150
#
#    dense_start_W  layersW  units_0W  dense_1S  dense_1dM  dense_2dM  units_1W  \
# 0            485        3       145       100        100        100       100
# 1            545        3       245       350        300        950       230
#
#    units_2W     Score
# 0       100  0.387291
# 1       545  0.410787
