# %%
#!/bin/python3

import math
import os
import random
import re
import sys


class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None


class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node

        self.tail = node


def print_singly_linked_list(node):
    while node:
        # fptr.write(str(node.data))
        print(node.data)

        node = node.next

        # if node:
        #     fptr.write(sep)

# Complete the mergeLists function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next
#
#


def mergeLists(head1, head2):
    root = SinglyLinkedListNode(-1)
    rc = root 
    while((head1 is not None) or (head2 is not None)):

        if(head2 == None):
            root.next = head1
            root = head1 
            head1 = head1.next
        elif(head1 == None):
            root.next = head2
            root = head2 
            head2 = head2.next
        if(head1 is not None and head2 is not None): 
            if(head1.data <= head2.data):
                root.next = head1
                root = head1
                head1 = head1.next
            else:
                root.next = head2
                root = head2
                head2 = head2.next
    return rc.next 
            

       


    

LL = SinglyLinkedList()
LL.insert_node(1)
LL.insert_node(2)
LL.insert_node(3) 

KK = SinglyLinkedList()
KK.insert_node(3)
KK.insert_node(4)

# print_singly_linked_list(LL.head)
# print_singly_linked_list(KK.head)

root = mergeLists(LL.head, KK.head)
# print_singly_linked_list(root)
# Out:
# -1
#
# -1
# 1
# 2
# 3
#
# -1
# 1
# 2
# 3
#
# -1
# 1
# 2
# 3
#
# -1
# 1
# 2
# 3
# 3
# 4
#
# -1
# 1
# 2
# 3
# 3
# 4
